# %% [markdown]
# ## Chapter - 1: Basics of Pandas
#
# ### Import packages and modules to be used in the example

# %%
# Render plots inline
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read CSV
#
# #### Setting index col as construction for plotting charts

# %%
sample_data = pd.read_csv("FL_insurance_sample.csv", index_col="construction")

# %% [markdown]
# ### Check first 5 rows in the data

# %%
sample_data.head(5)
# Out:
#               policyID statecode       county  eq_site_limit  hu_site_limit  \
# construction
# Masonry         119736        FL  CLAY COUNTY       498960.0      498960.00
# Masonry         448094        FL  CLAY COUNTY      1322376.3     1322376.30
# Wood            206893        FL  CLAY COUNTY       190724.4      190724.40
# Wood            333743        FL  CLAY COUNTY            0.0       79520.76
# Wood            172534        FL  CLAY COUNTY            0.0      254281.50
#
#               fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  \
# construction
# Masonry            498960.0       498960.0   498960.00   792148.90
# Masonry           1322376.3      1322376.3  1322376.30  1438163.57
# Wood               190724.4       190724.4   190724.40   192476.78
# Wood                    0.0            0.0    79520.76    86854.48
# Wood                    0.0       254281.5   254281.50   246144.49
#
#               eq_site_deductible  hu_site_deductible  fl_site_deductible  \
# ...

# %% [markdown]
# ### Select first 3 columns and five rows

# %%
sample_data.iloc[:5, :3]
# Out:
#               policyID statecode       county
# construction
# Masonry         119736        FL  CLAY COUNTY
# Masonry         448094        FL  CLAY COUNTY
# Wood            206893        FL  CLAY COUNTY
# Wood            333743        FL  CLAY COUNTY
# Wood            172534        FL  CLAY COUNTY

# %% [markdown]
# #### Select a single column 'county'

# %%
sample_data['county']
# Out:
# construction
# Masonry                    CLAY COUNTY
# Masonry                    CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Masonry                    CLAY COUNTY
# Reinforced Concrete        CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Masonry                    CLAY COUNTY
# Masonry                    CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Reinforced Concrete        CLAY COUNTY
# Masonry                    CLAY COUNTY
# Wood                       CLAY COUNTY
# ...

# %% [markdown]
# #### Select column 'county' (another way)

# %%
sample_data.county
# Out:
# construction
# Masonry                    CLAY COUNTY
# Masonry                    CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Masonry                    CLAY COUNTY
# Reinforced Concrete        CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Masonry                    CLAY COUNTY
# Masonry                    CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Wood                       CLAY COUNTY
# Reinforced Concrete        CLAY COUNTY
# Masonry                    CLAY COUNTY
# Wood                       CLAY COUNTY
# ...

# %% [markdown]
# ### To check in what kind of construction what is the site limit

# %%
sample_data['eq_site_limit'].plot()
