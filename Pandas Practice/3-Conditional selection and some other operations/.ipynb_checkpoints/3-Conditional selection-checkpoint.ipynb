# %% [markdown]
# ### Day 3: Advanced Slicing and dicing
#
# #### Load packages

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Read csv and check type of data in the dataframe

# %%
df = pd.read_csv('../Data/FL_insurance_sample.csv')

df.head()
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 0    119736        FL  CLAY COUNTY       498960.0      498960.00
# 1    448094        FL  CLAY COUNTY      1322376.3     1322376.30
# 2    206893        FL  CLAY COUNTY       190724.4      190724.40
# 3    333743        FL  CLAY COUNTY            0.0       79520.76
# 4    172534        FL  CLAY COUNTY            0.0      254281.50
#
#    fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  eq_site_deductible  \
# 0       498960.0       498960.0   498960.00   792148.90                 0.0
# 1      1322376.3      1322376.3  1322376.30  1438163.57                 0.0
# 2       190724.4       190724.4   190724.40   192476.78                 0.0
# 3            0.0            0.0    79520.76    86854.48                 0.0
# 4            0.0       254281.5   254281.50   246144.49                 0.0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# ...

# %% [markdown]
# ### Select only those rows where line is 'Residential'

# %%
residential_line = df[df['line']=='Residential']

# %% [markdown]
# #### Lets check the first 5 rows

# %%
residential_line[:5]
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 0    119736        FL  CLAY COUNTY       498960.0      498960.00
# 1    448094        FL  CLAY COUNTY      1322376.3     1322376.30
# 2    206893        FL  CLAY COUNTY       190724.4      190724.40
# 3    333743        FL  CLAY COUNTY            0.0       79520.76
# 4    172534        FL  CLAY COUNTY            0.0      254281.50
#
#    fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  eq_site_deductible  \
# 0       498960.0       498960.0   498960.00   792148.90                 0.0
# 1      1322376.3      1322376.3  1322376.30  1438163.57                 0.0
# 2       190724.4       190724.4   190724.40   192476.78                 0.0
# 3            0.0            0.0    79520.76    86854.48                 0.0
# 4            0.0       254281.5   254281.50   246144.49                 0.0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# ...

# %% [markdown]
# #### To select only those rows where line is 'Residential' and construction is 'Wood'
#
# #### Shwoing first 5 rows from the result set directly

# %%
residential_line[residential_line['construction']=='Wood'][:5]
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 2    206893        FL  CLAY COUNTY       190724.4      190724.40
# 3    333743        FL  CLAY COUNTY            0.0       79520.76
# 4    172534        FL  CLAY COUNTY            0.0      254281.50
# 7    223488        FL  CLAY COUNTY       328500.0      328500.00
# 8    433512        FL  CLAY COUNTY       315000.0      315000.00
#
#    fl_site_limit  fr_site_limit   tiv_2011   tiv_2012  eq_site_deductible  \
# 2       190724.4       190724.4  190724.40  192476.78                 0.0
# 3            0.0            0.0   79520.76   86854.48                 0.0
# 4            0.0       254281.5  254281.50  246144.49                 0.0
# 7       328500.0       328500.0  328500.00  348374.25                 0.0
# 8       315000.0       315000.0  315000.00  265821.57                 0.0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# ...

# %% [markdown]
# #### Select above data in a single step

# %%
df[(df['line'] == 'Residential') & (df['construction'] == 'Wood')][:5]
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 2    206893        FL  CLAY COUNTY       190724.4      190724.40
# 3    333743        FL  CLAY COUNTY            0.0       79520.76
# 4    172534        FL  CLAY COUNTY            0.0      254281.50
# 7    223488        FL  CLAY COUNTY       328500.0      328500.00
# 8    433512        FL  CLAY COUNTY       315000.0      315000.00
#
#    fl_site_limit  fr_site_limit   tiv_2011   tiv_2012  eq_site_deductible  \
# 2       190724.4       190724.4  190724.40  192476.78                 0.0
# 3            0.0            0.0   79520.76   86854.48                 0.0
# 4            0.0       254281.5  254281.50  246144.49                 0.0
# 7       328500.0       328500.0  328500.00  348374.25                 0.0
# 8       315000.0       315000.0  315000.00  265821.57                 0.0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# ...

# %% [markdown]
# #### We can also select few columns at single go

# %%
df[(df['line'] == 'Residential') & (df['construction'] == 'Wood')][['statecode', 'line', 'construction']][:5]
# Out:
#   statecode         line construction
# 2        FL  Residential         Wood
# 3        FL  Residential         Wood
# 4        FL  Residential         Wood
# 7        FL  Residential         Wood
# 8        FL  Residential         Wood

# %% [markdown]
# ### So to check which county has most residential claims

# %%
residential_line['county'].value_counts()
# Out:
# MIAMI DADE COUNTY      3343
# BROWARD COUNTY         2636
# PALM BEACH COUNTY      2256
# PINELLAS COUNTY        1547
# DUVAL COUNTY           1492
# ORANGE COUNTY          1407
# POLK COUNTY            1353
# VOLUSIA COUNTY         1169
# MARION COUNTY          1071
# OKALOOSA COUNTY        1061
# SEMINOLE COUNTY         941
# ALACHUA COUNTY          885
# HILLSBOROUGH COUNTY     861
# SANTA ROSA COUNTY       829
# BREVARD COUNTY          743
# PASCO COUNTY            647
# COLLIER COUNTY          624
# ST  JOHNS COUNTY        613
# LEE COUNTY              572
# ESCAMBIA COUNTY         420
# MANATEE COUNTY          411
# CITRUS COUNTY           352
# CHARLOTTE COUNTY        344
# CLAY COUNTY             341
# BAY COUNTY              332
# SARASOTA COUNTY         331
# HIGHLANDS COUNTY        322
# INDIAN RIVER COUNTY     321
# WALTON COUNTY           267
# PUTNAM COUNTY           261
#                        ...
# LEVY COUNTY             126
# NASSAU COUNTY           121
# ...

# %% [markdown]
# #### Check the type of construction in residential

# %%
residential_line['construction'].value_counts()
# Out:
# Wood       21581
# Masonry     9257
# Name: construction, dtype: int64

# %% [markdown]
# #### Check what percentage of total claims are residential claims for each county

# %%
total_claims = df['county'].value_counts()

residential_claims = residential_line['county'].value_counts()

(residential_claims/total_claims).astype(float)
# Out:
# ALACHUA COUNTY         0.909558
# BAKER COUNTY           0.985714
# BAY COUNTY             0.823821
# BRADFORD COUNTY        0.935484
# BREVARD COUNTY         0.852064
# BROWARD COUNTY         0.825556
# CALHOUN COUNTY         0.911765
# CHARLOTTE COUNTY       0.830918
# CITRUS COUNTY          0.916667
# CLAY COUNTY            0.939394
# COLLIER COUNTY         0.792884
# COLUMBIA COUNTY        0.920000
# DESOTO COUNTY          0.916667
# DIXIE COUNTY           0.950000
# DUVAL COUNTY           0.787751
# ESCAMBIA COUNTY        0.850202
# FLAGLER COUNTY         0.897059
# FRANKLIN COUNTY        0.864865
# GADSDEN COUNTY         0.913265
# GILCHRIST COUNTY       0.974359
# GLADES COUNTY          0.863636
# GULF COUNTY            0.916667
# HAMILTON COUNTY        1.000000
# HARDEE COUNTY          0.876543
# HENDRY COUNTY          0.851351
# HERNANDO COUNTY        0.825000
# HIGHLANDS COUNTY       0.872629
# HILLSBOROUGH COUNTY    0.738422
# HOLMES COUNTY          0.875000
# ...

# %% [markdown]
# #### Plot residential claims in a bar plot

# %%
plt.rcParams['figure.figsize'] = (20, 7)

# %%
residential_claims[:10].plot(kind="bar")
